# %% [markdown]
# #Imagen Digital

# %%
import requests
import matplotlib.pyplot as plt
import numpy as np
import cv2
from  PIL import Image
from  io import BytesIO

# %%
url       = "https://www.anicura.es/cdn-cgi/image/f=auto,fit=cover,w=520,h=520,g=auto,sharpen=1/AdaptiveImages/powerinit/52437/_SNI2031.jpg?stamp=a2efc90c9d13cd9fdc0f5f7a2e3b2231238dc8cf"
response  = requests.get(url)
response.raise_for_status()
image     = Image.open(BytesIO(response.content))

plt.imshow(image)
plt.axis("off")
plt.show()

# %%
type(image)
# Out:
# PIL.JpegImagePlugin.JpegImageFile

# %%
img = np.array(image)
plt.imshow(img)
plt.axis("off")
plt.show()

# %%
img
# Out:
# array([[[235, 235, 245],
#         [235, 235, 245],
#         [234, 234, 244],
#         ...,
#         [247, 246, 251],
#         [247, 246, 251],
#         [247, 246, 251]],
#
#        [[234, 234, 244],
#         [234, 234, 244],
#         [233, 233, 243],
#         ...,
#         [247, 246, 251],
#         [247, 246, 251],
#         [247, 246, 251]],
#
#        [[232, 232, 240],
#         [232, 232, 240],
#         [232, 232, 240],
#         ...,
#         [247, 247, 249],
#         [247, 247, 249],
#         [247, 247, 249]],
#
#        ...,
#
#        [[ 69,  51,  41],
#         [ 69,  51,  41],
#         [ 70,  52,  42],
#         ...,
#         [247, 247, 245],
#         [246, 246, 244],
#         [245, 245, 243]],
#
#        [[ 69,  51,  41],
#         [ 70,  52,  42],
#         [ 70,  52,  42],
#         ...,
#         [247, 247, 245],
#         [246, 246, 244],
#         [246, 246, 244]],
#
#        [[ 70,  52,  42],
#         [ 70,  52,  42],
#         [ 70,  52,  42],
#         ...,
#         [247, 247, 245],
#         [247, 247, 245],
#         [246, 246, 244]]], dtype=uint8)

# %%
response = requests.get(url)
response.raise_for_status()

image_array = np.asarray(bytearray(response.content), dtype=np.uint8)
image = cv2.imdecode(image_array, cv2.IMREAD_COLOR)

print(f"Dimensiones: {image.shape}")
print(f"Tipo de dato: {image.dtype}")

plt.imshow(image)
plt.axis("off")
plt.show()
# Out:
# Dimensiones: (520, 520, 3)
# Tipo de dato: uint8

# %%
image.shape
# Out:
# (520, 520, 3)

# %%
image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)  # Convertir BGR a RGB para matplotlib
plt.imshow(image_rgb)
plt.axis("off")
plt.show()

# %%
type(image_rgb)
# Out:
# numpy.ndarray

# %%
print(f"Formato: {image.format}")
print(f"Tamaño: {image.size}")
print(f"Modo de color: {image.mode}")
print(f"Información extra: {image.info}")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-1310553576.py in <cell line: 0>()
# ----> 1 print(f"Formato: {image.format}")
#       2 print(f"Tamaño: {image.size}")
#       3 print(f"Modo de color: {image.mode}")
#       4 print(f"Información extra: {image.info}")
#
# AttributeError: 'numpy.ndarray' object has no attribute 'format'

# %%
img = image_rgb
img.shape
# Out:
# (520, 520, 3)

# %%
img[0]
# Out:
# array([[235, 235, 245],
#        [235, 235, 245],
#        [234, 234, 244],
#        ...,
#        [247, 246, 251],
#        [247, 246, 251],
#        [247, 246, 251]], dtype=uint8)

# %%
plt.imshow(img[80:300,200:450,0], cmap="gray")
plt.show()

# %%
# Convert the image to grayscale
gray_image = cv2.cvtColor(image_rgb, cv2.COLOR_RGB2GRAY)

# Display the grayscale image
plt.imshow(gray_image, cmap='gray')
plt.axis("off")
plt.show()

# %%
grayscale = np.linspace(0, 255, 256).astype(np.uint8)
gradient = np.tile(grayscale, (50, 1))

plt.figure(figsize=(10, 2))
plt.imshow(gradient, cmap="gray", aspect="auto")
plt.show()
